# %% [markdown]
# <h1 style="color:#0e0b29;text-align: center;font-weight: bold">Universidad Castro Carazo</h1>
# <h5 style="color:#3b0032;text-align: center">Analisis de Datos</h5>
# <h5 style="color:#7d2948;text-align: center">Proyecto Venta Bienes Raíces</h5>

# %% [markdown]
# <table>
#   <tr>
#     <td>Paleta de Colores</td>
#     <td> <a href="https://paletadecolores.com.mx/paleta/ebeaa9/ebc588/7d2948/3b0032/0e0b29/" >Enlace al Sitio Web</a> </td>
#   </tr>
# </table>

# %%
import numpy as np 
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sn

import warnings 
warnings.filterwarnings("ignore")

# %%
dfCasa = pd.read_csv('dataSet.csv', sep=';', engine='python')
print("Se cargaron los datos a la memoria")
# Out:
# Se cargaron los datos a la memoria

# %%
dfCasa.head(5)

# %%
dfCasa.tail(5)
# Out:
#        Serial Number List Year Date Recorded           Town         Address  \
# 190015         20763      2002     6/17/2003     West Haven    130 JONES ST
# 190016         21066      2002     7/22/2003  West Hartford    15 PORTER DR
# 190017         30531      2003     4/15/2004  East Hartford   43 TIFFANY RD
# 190018         30624      2003      3/3/2004        Bristol   81 ANDREWS ST
# 190019         30434      2003      2/6/2004      Greenwich  57 PROSPECT ST
#
#        Assessed Value Sale Amount  Sales Ratio Property Type Residential Type  \
# 190015          70700      179000  0.394972067           NaN              NaN
# 190016         240880      515000  0.467728155           NaN              NaN
# 190017          80330      130000  0.617923077           NaN              NaN
# 190018          69230      130000  0.532538462           NaN              NaN
# 190019         183470      375000  0.489253333           NaN              NaN
#
# ...

# %%
dfCasa.shape
# Out:
# (190020, 139)

# %%
dfCasa.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type',
#        ...
#        'Unnamed: 129', 'Unnamed: 130', 'Unnamed: 131', 'Unnamed: 132',
#        'Unnamed: 133', 'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136',
#        'Unnamed: 137', 'Unnamed: 138'],
#       dtype='object', length=139)

# %%
dfCasa.rename({'Serial Number':'serialNumber', 'List Year':'listYear', 'Date Recorded':'dateRecorded','Town':'town', 'Address':'address','Assessed Value': 'assessedValue', 'Sale Amount':'saleAmount', 'Sales Ratio':'salesRatio', 'Property Type':'propertyType',
       'Residential Type': 'residentialType'},axis=1, inplace=True)
dfCasa.columns
# Out:
# Index(['serialNumber', 'listYear', 'dateRecorded', 'town', 'address',
#        'assessedValue', 'saleAmount', 'salesRatio', 'propertyType',
#        'residentialType',
#        ...
#        'Unnamed: 129', 'Unnamed: 130', 'Unnamed: 131', 'Unnamed: 132',
#        'Unnamed: 133', 'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136',
#        'Unnamed: 137', 'Unnamed: 138'],
#       dtype='object', length=139)

# %%
dfCasa.head(10)
# Out:
#   serialNumber listYear dateRecorded     town                address  \
# 0      2020348     2020    9/13/2021  Ansonia        230 WAKELEE AVE
# 1        20002     2020    10/2/2020  Ashford        390 TURNPIKE RD
# 2       200212     2020     3/9/2021     Avon       5 CHESTNUT DRIVE
# 3       200243     2020    4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4       200377     2020     7/2/2021     Avon     70 FAR HILLS DRIVE
# 5       200109     2020    12/9/2020     Avon     57 FAR HILLS DRIVE
# 6      2020180     2020     3/1/2021   Berlin    1539 FARMINGTON AVE
# 7      2020313     2020     7/1/2021   Berlin      216 WATCH HILL RD
# 8       200097     2020     6/4/2021  Bethany            23 AMITY RD
# 9        20139     2020   12/16/2020   Bethel      16 DEEPWOOD DRIVE
#
#   assessedValue saleAmount salesRatio propertyType residentialType  ...  \
# 0        150500     325000      0.463   Commercial             NaN  ...
# ...

# %%
dfCasa['residentialType'].unique()
# Out:
# array([nan, 'Single Family', 'Condo', 'Two Family', 'Three Family',
#        'Four Family', 'POINT (-72.49422 41.78123)'], dtype=object)

# %%
dfCasa['propertyType'].unique()
# Out:
# array(['Commercial', 'Residential', 'Vacant Land', nan, 'Apartments',
#        'Industrial', 'Public Utility', 'Condo', 'Two Family',
#        ';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;',
#        'Three Family', 'Single Family'], dtype=object)

# %%
dfCasa['saleAmount'].unique()
# Out:
# array(['325000', '430000', '179900', ..., '269995', '298999', '824860'],
#       dtype=object)

# %%
dfCasa['salesRatio'].unique()
# Out:
# array(['0.463', '0.5883', '0.7248', ..., '0.617923077', '0.532538462',
#        '0.489253333'], dtype=object)

# %%
dfCasa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190020 entries, 0 to 190019
# Columns: 139 entries, serialNumber to Unnamed: 138
# dtypes: float64(65), object(74)
# memory usage: 201.5+ MB

# %%
dfCasa['town'].unique()
# Out:
# array(['Ansonia', 'Ashford', 'Avon', 'Berlin', 'Bethany', 'Bethel',
#        'Bethlehem', 'Bloomfield', 'Branford', 'Bristol', 'Brookfield',
#        'Canaan', 'Canton', 'Cheshire', 'Chester', 'Colchester',
#        'Columbia', 'Cornwall', 'Coventry', 'Cromwell', 'Danbury', 'Derby',
#        'Eastford', 'East Haddam', 'East Haven', 'Farmington', 'Chaplin',
#        'Clinton', 'East Lyme', 'Easton', 'Enfield', 'Essex', 'Durham',
#        'Franklin', 'Glastonbury', 'Hamden', 'Granby', 'Greenwich',
#        'Colebrook', 'East Windsor', 'Griswold', 'Bolton', 'Groton',
#        'Guilford', 'Hartford', 'Harwinton', 'Milford', 'Killingly',
#        'Killingworth', 'Lebanon', 'Lisbon', 'Litchfield', 'Lyme',
#        'Manchester', 'Putnam', 'Norwalk', 'Stafford', 'Mansfield',
#        'Sherman', 'Meriden', 'Stratford', 'Roxbury', 'Oxford', 'Old Lyme',
#        'Norwich', 'Sharon', 'Monroe', 'Tolland', 'Torrington',
#        'Naugatuck', 'Ridgefield', 'New London', 'New Britain', 'Orange',
# ...

# %%
dfCasa.replace('POINT (-72.49422 41.78123)',np.nan, inplace=True)
dfCasa['residentialType'].unique()
# Out:
# array([nan, 'Single Family', 'Condo', 'Two Family', 'Three Family',
#        'Four Family'], dtype=object)

# %%
dfTemp=dfCasa.isnull()
dfTemp.head(2)
# Out:
#    serialNumber  listYear  dateRecorded   town  address  assessedValue  \
# 0         False     False         False  False    False          False
# 1         False     False         False  False    False          False
#
#    saleAmount  salesRatio  propertyType  residentialType  ...  Unnamed: 129  \
# 0       False       False         False             True  ...          True
# 1       False       False         False            False  ...          True
#
#    Unnamed: 130  Unnamed: 131  Unnamed: 132  Unnamed: 133  Unnamed: 134  \
# 0          True          True          True          True          True
# 1          True          True          True          True          True
#
#    Unnamed: 135  Unnamed: 136  Unnamed: 137  Unnamed: 138
# 0          True          True          True          True
# 1          True          True          True          True
#
# [2 rows x 139 columns]

# %%
dfCasa= dfCasa.dropna(axis=1, how='all')
dfCasa.head(2)
# Out:
#   serialNumber listYear dateRecorded     town          address assessedValue  \
# 0      2020348     2020    9/13/2021  Ansonia  230 WAKELEE AVE        150500
# 1        20002     2020    10/2/2020  Ashford  390 TURNPIKE RD        253000
#
#   saleAmount salesRatio propertyType residentialType  ... Unnamed: 113  \
# 0     325000      0.463   Commercial             NaN  ...          NaN
# 1     430000     0.5883  Residential   Single Family  ...          NaN
#
#   Unnamed: 117 Unnamed: 118 Unnamed: 122 Unnamed: 123 Unnamed: 127  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 128 Unnamed: 132 Unnamed: 133 Unnamed: 138
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
#
# [2 rows x 74 columns]

# %%
for columns in dfTemp.columns.values.tolist():
    print(dfTemp[columns].value_counts())
    print('')
# Out:
# serialNumber
# False    190008
# True         12
# Name: count, dtype: int64
#
# listYear
# False    189946
# True         74
# Name: count, dtype: int64
#
# dateRecorded
# False    189940
# True         80
# Name: count, dtype: int64
#
# town
# False    189943
# True         77
# Name: count, dtype: int64
#
# address
# False    189934
# True         86
# Name: count, dtype: int64
#
# assessedValue
# False    189936
# True         84
# Name: count, dtype: int64
#
# saleAmount
# False    189935
# True         85
# Name: count, dtype: int64
#
# salesRatio
# False    189934
# True         86
# Name: count, dtype: int64
#
# propertyType
# True     133437
# False     56583
# Name: count, dtype: int64
#
# residentialType
# True     138374
# False     51646
# Name: count, dtype: int64
#
# Non Use Code
# True     146702
# False     43318
# Name: count, dtype: int64
#
# Assessor Remarks
# True     177964
# False     12056
# Name: count, dtype: int64
#
# OPM remarks
# True     188279
# ...

# %%
dfTemp=dfCasa[dfCasa.assessedValue.isnull()]
dfTemp.head(5)

#serialNumber	listYear	dateRecorded	town	address	assessedValue	saleAmount	salesRatio	propertyType	residentialType
# Out:
#                                             serialNumber listYear  \
# 15608                                              20099     2020
# 18444                                                NaN      NaN
# 20070                                              20070     2020
# 20776                                             200002     2020
# 21270  201248;2020;9/22/2021;Hartford;178 PRESTON ST ...      NaN
#
#       dateRecorded         town            address assessedValue saleAmount  \
# 15608     8/9/2021       Lisbon            MELL RD           NaN        NaN
# 18444          NaN          NaN                NaN           NaN        NaN
# 20070     6/2/2021       Lisbon               REAR           NaN        NaN
# 20776    10/5/2020  Bridgewater  79 SECOND HILL RD           NaN        NaN
# 21270          NaN          NaN                NaN           NaN        NaN
#
#       salesRatio propertyType residentialType  ... Unnamed: 113 Unnamed: 117  \
# ...

# %%
dfTemp=dfCasa[dfCasa.address.isnull()]
dfTemp.head(5)
# Out:
#                                             serialNumber listYear  \
# 18444                                                NaN      NaN
# 21270  201248;2020;9/22/2021;Hartford;178 PRESTON ST ...      NaN
# 21317  200204;2020;12/23/2020;Branford;18 HAMPTON PAR...      NaN
# 21318                                            roperty      NaN
# 21403  20072;2020;7/6/2021;Barkhamsted;245 NEW HARTFO...      NaN
#
#       dateRecorded town address assessedValue saleAmount salesRatio  \
# 18444          NaN  NaN     NaN           NaN        NaN        NaN
# 21270          NaN  NaN     NaN           NaN        NaN        NaN
# 21317          NaN  NaN     NaN           NaN        NaN        NaN
# 21318          NaN  NaN     NaN           NaN        NaN        NaN
# 21403          NaN  NaN     NaN           NaN        NaN        NaN
#
#       propertyType residentialType  ...  \
# 18444          NaN             NaN  ...
# 21270          NaN             NaN  ...
# ...

# %%
dfTemp=dfCasa[dfCasa.assessedValue.isnull()]
dfTemp.head(5)
# Out:
#                                             serialNumber listYear  \
# 15608                                              20099     2020
# 18444                                                NaN      NaN
# 20070                                              20070     2020
# 20776                                             200002     2020
# 21270  201248;2020;9/22/2021;Hartford;178 PRESTON ST ...      NaN
#
#       dateRecorded         town            address assessedValue saleAmount  \
# 15608     8/9/2021       Lisbon            MELL RD           NaN        NaN
# 18444          NaN          NaN                NaN           NaN        NaN
# 20070     6/2/2021       Lisbon               REAR           NaN        NaN
# 20776    10/5/2020  Bridgewater  79 SECOND HILL RD           NaN        NaN
# 21270          NaN          NaN                NaN           NaN        NaN
#
#       salesRatio propertyType residentialType  ... Unnamed: 113 Unnamed: 117  \
# ...

# %%
dfTemp=dfCasa[dfCasa.salesRatio.isnull()]
dfTemp.head(5)
# Out:
#                                             serialNumber listYear  \
# 15608                                              20099     2020
# 18444                                                NaN      NaN
# 20070                                              20070     2020
# 20776                                             200002     2020
# 21270  201248;2020;9/22/2021;Hartford;178 PRESTON ST ...      NaN
#
#       dateRecorded         town            address assessedValue saleAmount  \
# 15608     8/9/2021       Lisbon            MELL RD           NaN        NaN
# 18444          NaN          NaN                NaN           NaN        NaN
# 20070     6/2/2021       Lisbon               REAR           NaN        NaN
# 20776    10/5/2020  Bridgewater  79 SECOND HILL RD           NaN        NaN
# 21270          NaN          NaN                NaN           NaN        NaN
#
#       salesRatio propertyType residentialType  ... Unnamed: 113 Unnamed: 117  \
# ...

# %%
dfTemp=dfCasa[dfCasa.propertyType.isnull()]
dfTemp.head(5)
# Out:
#    serialNumber listYear dateRecorded        town       address assessedValue  \
# 48        10095     2001   11/16/2001  Farmington  5 SPARROW LN         67670
# 50        11238     2001    8/30/2002      Bethel  50 FOURTH ST         76450
# 51        10035     2001    6/28/2002     Chaplin    FEDERAL RD         19000
# 52        10115     2001     2/1/2002     Clinton   42 PRATT RD        121900
# 60        10041     2001    7/17/2002    Eastford   WESTFORD RD           180
#
#    saleAmount   salesRatio propertyType residentialType  ... Unnamed: 113  \
# 48     302866  0.223432145          NaN             NaN  ...          NaN
# 50      50000        1.529          NaN             NaN  ...          NaN
# 51      35000  0.542857143          NaN             NaN  ...          NaN
# 52     230000         0.53          NaN             NaN  ...          NaN
# 60       5000        0.036          NaN             NaN  ...          NaN
#
# ...

# %%
dfCasa.columns = dfCasa.columns.str.strip()

# %%
print(dfCasa.dtypes)
# Out:
# serialNumber    object
# listYear        object
# dateRecorded    object
# town            object
# address         object
#                  ...
# Unnamed: 127    object
# Unnamed: 128    object
# Unnamed: 132    object
# Unnamed: 133    object
# Unnamed: 138    object
# Length: 74, dtype: object

# %%
columnas_numericas = dfCasa.select_dtypes(include=['int64', 'float64']).columns.tolist()

columnas_no_numericas = dfCasa.select_dtypes(include=['object']).columns.tolist()

print("Columnas numéricas:", columnas_numericas)
print("Columnas NO numéricas:", columnas_no_numericas)
# Out:
# Columnas numéricas: []
# ...

# %%
for col in columnas_no_numericas:
    try:
        dfCasa[col] = pd.to_numeric(dfCasa[col], errors='raise')
        promedio = dfCasa[col].mean()
        imputacionNumerica(col, promedio, dfCasa)
    except:
        print(f"Columna '{col}' no se puede convertir a numérica. Se omite.")
# Out:
# Columna 'serialNumber' no se puede convertir a numérica. Se omite.
# Columna 'listYear' no se puede convertir a numérica. Se omite.
# Columna 'dateRecorded' no se puede convertir a numérica. Se omite.
# Columna 'town' no se puede convertir a numérica. Se omite.
# Columna 'address' no se puede convertir a numérica. Se omite.
# Columna 'assessedValue' no se puede convertir a numérica. Se omite.
# Columna 'saleAmount' no se puede convertir a numérica. Se omite.
# Columna 'salesRatio' no se puede convertir a numérica. Se omite.
# Columna 'propertyType' no se puede convertir a numérica. Se omite.
# Columna 'residentialType' no se puede convertir a numérica. Se omite.
# Columna 'Non Use Code' no se puede convertir a numérica. Se omite.
# Columna 'Assessor Remarks' no se puede convertir a numérica. Se omite.
# Columna 'OPM remarks' no se puede convertir a numérica. Se omite.
# Columna 'Location' no se puede convertir a numérica. Se omite.
# ...

# %%
def imputacionNumerica(variable, valor, df):
    df[variable].fillna(valor, inplace=True)

def imputar_columnas_numericas(df, dataSet='dfCasa_imputado.csv'):
    resumen = []

    columnas_irrelevantes = [col for col in df.columns if 'Unnamed' in col or df[col].isnull().all()]
    df.drop(columns=columnas_irrelevantes, inplace=True)
    print(f" Columnas irrelevantes eliminadas: {columnas_irrelevantes}")

    for col in df.columns:
        try:
        
            df[col] = pd.to_numeric(df[col], errors='raise')

            if df[col].notna().sum() > 0:
                promedio = df[col].mean()
                imputacionNumerica(col, promedio, df)
                resumen.append((col, promedio))
                print(f" Imputado '{col}' con promedio: {promedio}")
            else:
                print(f" Columna '{col}' solo contiene NaNs. No se imputa.")
        except:
            print(f" Columna '{col}' no es numérica. Se omite.")

    df.to_csv(dataSet, index=False)
    print(f"\n Archivo guardado como '{dataSet}'")


    if resumen:
        print("\n Resumen de imputación:")
        for col, valor in resumen:
            print(f" - {col}: imputado con {valor}")
    else:
        print("\n No se imputó ninguna columna.")

    return resumen

# %%
resumen_imputacion = imputar_columnas_numericas(dfCasa)
# Out:
#  Columnas irrelevantes eliminadas: ['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 72', 'Unnamed: 73', 'Unnamed: 77', 'Unnamed: 78', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 92', 'Unnamed: 93', 'Unnamed: 97', 'Unnamed: 98', 'Unnamed: 99', 'Unnamed: 102', 'Unnamed: 103', 'Unnamed: 107', 'Unnamed: 108', 'Unnamed: 112', 'Unnamed: 113', 'Unnamed: 117', 'Unnamed: 118', 'Unnamed: 122', 'Unnamed: 123', 'Unnamed: 127', 'Unnamed: 128', 'Unnamed: 132', 'Unnamed: 133', 'Unnamed: 138']
#  Columna 'serialNumber' no es numérica. Se omite.
# ...

# %%
dfCasa.head(2)
# Out:
#   serialNumber listYear dateRecorded     town          address assessedValue  \
# 0      2020348     2020    9/13/2021  Ansonia  230 WAKELEE AVE        150500
# 1        20002     2020    10/2/2020  Ashford  390 TURNPIKE RD        253000
#
#   saleAmount salesRatio propertyType residentialType Non Use Code  \
# 0     325000      0.463   Commercial             NaN          NaN
# 1     430000     0.5883  Residential   Single Family          NaN
#
#   Assessor Remarks OPM remarks Location  \
# 0              NaN         NaN      NaN
# 1              NaN         NaN      NaN
#
#   ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 0  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...
# 1  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...

# %%
dfCasa.dropna(subset=['Non Use Code'],axis=0,inplace=True)

# %%
dfCasa.dropna(subset=['Assessor Remarks'],axis=0,inplace=True)

# %%
dfCasa.dropna(subset=['OPM remarks'],axis=0,inplace=True)

# %%
dfCasa.dropna(subset=['Location'],axis=0,inplace=True)

# %%
def missing_cols(dfCasa):
    total = 0
    for col in dfCasa.columns:
        missing_vals = dfCasa[col].isnull().sum()
        total += missing_vals
        if missing_vals != 0:
            print(f'{col} => {dfCasa[col].isnull().sum()}')
    if total == 0:
        print('No hay valores faltantes')
 
missing_cols(dfCasa)
# Out:
# residentialType => 11
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, => 22

# %%
def eliminar_columnas_irrelevantes(df):
    columnas_a_eliminar = [col for col in df.columns if 'Unnamed' in col or col.strip().startswith(',')]
    print(f"Eliminando columnas: {columnas_a_eliminar}")
    df.drop(columns=columnas_a_eliminar, inplace=True)
    return df

# %%
dfCasa = eliminar_columnas_irrelevantes(dfCasa)
missing_cols(dfCasa)
# Out:
# Eliminando columnas: [',,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,']
# residentialType => 11

# %%
dfCasa['town'].unique()
# Out:
# array(['Danbury', 'Cheshire', 'Avon', 'Brookfield', 'Colchester',
#        'Griswold', 'East Lyme', 'Barkhamsted', 'Ashford', 'Coventry',
#        'East Hartford', 'East Granby', 'Bristol', 'Farmington', 'Norwalk',
#        'South Windsor', 'North Haven', 'Portland', 'Montville',
#        'Southbury', 'New Haven', 'Shelton', 'Middletown', 'Old Saybrook',
#        'Plymouth', 'Tolland', 'Suffield', 'Thomaston', 'Willington',
#        'Wolcott'], dtype=object)

# %%
dfCasa['address'].unique()
# Out:
# array(['8 HICKORY ST', '19  MILL RD', '32 COALPIT HILL RD #4',
#        'M58 L12 WIESE RD', '23 CHEPACHET ROAD', '11 BRISTOL PATH',
#        '28 PHOENIX RD', '32 COALPIT HILL RD #6', '20 BROWNING RD',
#        '1 E HAYESTOWN RD #155', '249 OLD BLACK PT RD', '49 BRENTWOOD CI',
#        '32 COALPIT HILL RD #8', '32 COALPIT HILL RD #12',
#        '19 RIDGECREST RD', '6 PLEASANT DR', '82 TAYLOR RD', '5 MAPLE DR',
#        '72 WARNER RD', '42  S LEE RD', '26 CROSS ST', '59 BRENTWOOD CI',
#        '5 CATHERINE ST', 'JUDITH DR LOT 33', '81-95 PARK AV 905',
#        '32 COALPIT HILL RD #2', '50 BOULEVARD DR',
#        '32 COALPIT HILL RD #1', '147 BRENTWOOD CI', '16 E HAYESTOWN RD',
#        '2 VENTURA AV', '44 JEANETTE RD', '32 COALPIT HILL RD #9',
#        '64 S WASHINGTON AVE', '14 WEST CROSS TR', '110 WANGUMBAUG DR',
#        '57 SHAWNEE RD', '6 QUIEN ST', '43 KOHANZA ST #43',
#        '167 SOUTH MAIN STREET', '325 PECK LN', '11 KELSEY COURT',
# ...

# %%
dfCasa['propertyType'].unique()
# Out:
# array(['Residential', 'Vacant Land', 'Commercial', 'Industrial'],
#       dtype=object)

# %%
dfCasa['residentialType'].unique()
# Out:
# array(['Single Family', 'Condo', nan, 'Two Family', 'Three Family'],
#       dtype=object)

# %%
dfCasa['town'] = dfCasa['town'].str.upper() 
dfCasa['propertyType'] = dfCasa['propertyType'].str.upper() 
dfCasa['residentialType'] = dfCasa['residentialType'].str.upper() 
dfCasa['address'] = dfCasa['address'].str.upper()

# %%
dfCasa.head(3)
# Out:
#      serialNumber listYear dateRecorded     town                address  \
# 806        200594     2020    2/16/2021  DANBURY           8 HICKORY ST
# 981        200562     2020     2/3/2021  DANBURY            19  MILL RD
# 1529       200260     2020   11/23/2020  DANBURY  32 COALPIT HILL RD #4
#
#      assessedValue saleAmount   salesRatio propertyType residentialType  \
# 806         121600     146216  0.831646331  RESIDENTIAL   SINGLE FAMILY
# 981         263600     415000  0.635180723  RESIDENTIAL   SINGLE FAMILY
# 1529         84900     181778  0.467053219  RESIDENTIAL           CONDO
#
#      Non Use Code                   Assessor Remarks  \
# 806    25 - Other                             I11192
# 981    25 - Other  AFFORDABLE HOUSING / B15001-20-19
# 1529   25 - Other                           J16087-4
#
#                           OPM remarks                    Location
# 806         HOUSE HAS SETTLED PER MLS  POINT (-73.44696 41.41179)
# ...

# %%
dfCasa['dateRecorded'] = pd.to_datetime(dfCasa['dateRecorded'])
dfCasa['year'] = dfCasa['dateRecorded'].dt.year
ingreso_anual = dfCasa.groupby('year')['saleAmount'].sum()

# %%
facilidad_venta =facilidad_venta = dfCasa.groupby('propertyType')['salesRatio'].mean().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
costo_promedio_tipo = dfCasa.groupby('propertyType')['saleAmount'].mean()

# %% [markdown]
# <h5 style="color:#3b0032;text-align: Center">**Visualizacion de Datos**</h5>

# %% [markdown]
# <h5 style="color:#0e0b29;text-align: rigth">1. Cuál es el ingreso anual de las propiedades vendidas? </h5>

# %%
years = ingreso_anual.index.astype(str)
income = ingreso_anual.values

plt.figure(figsize=(10, 6))
plt.bar(years, income, color='skyblue')
plt.title("Ingreso anual por venta de propiedades")
plt.xlabel("Año")
plt.ylabel("Ingreso ($)")
plt.xticks(rotation=10)
plt.tight_layout()

plt.show()

# %% [markdown]
# <h5 style="color:#0e0b29;text-align: rigth"> Qué tipo de propiedad tiene mayor facilidad de venta?  </h5>

# %%
dfCasa['salesRatio'] = pd.to_numeric(dfCasa['salesRatio'], errors='coerce')

tipos = facilidad_venta.index
ratios = facilidad_venta.values
plt.figure(figsize=(10, 6))
plt.bar(tipos, ratios, color='mediumseagreen')
plt.title("Facilidad de venta por tipo de propiedad (promedio de Sales Ratio)")
plt.xlabel("Tipo de propiedad")
plt.ylabel("Promedio de Sales Ratio")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5 style="color:#0e0b29;text-align: rigth">En cuál ciudad o pueblo se dan mayor cantidad de ventas de
# propiedades?   </h5>

# %%
ventas_ciudad = dfCasa['town'].value_counts().head(10)

plt.figure(figsize=(8, 8))
plt.pie(ventas_ciudad, labels=ventas_ciudad.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribución de ventas por ciudad/pueblo (Top 10)")
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5 style="color:#0e0b29;text-align: rigth">¿Cuál es el costo promedio de las propiedades residenciales y
# comerciales?  </h5>

# %%
dfCasa['saleAmount'] = pd.to_numeric(dfCasa['saleAmount'], errors='coerce')
dfCasa['propertyType'] = dfCasa['propertyType'].astype(str).str.strip().str.upper()
filtered_dfCasa = dfCasa[dfCasa['propertyType'].isin(['RESIDENTIAL', 'COMMERCIAL'])]
average_cost = filtered_dfCasa.groupby('propertyType')['saleAmount'].mean()

plt.figure(figsize=(8, 6))
average_cost.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Costo Promedio por Tipo de Propiedad')
plt.ylabel('Costo Promedio (USD)')
plt.xlabel('Tipo de Propiedad')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h5 style="color:#0e0b29;text-align: rigth">¿Cuál es margen promedio de ganancia por cada una de las
# propiedades vendidas?   </h5>

# %%
dfCasa['saleAmount'] = pd.to_numeric(dfCasa['saleAmount'], errors='coerce')
dfCasa['assessedValue'] = pd.to_numeric(dfCasa['assessedValue'], errors='coerce')
dfCasa['margen_ganancia'] = ((dfCasa['saleAmount'] - dfCasa['assessedValue']) / dfCasa['assessedValue']) * 100
margen_promedio = dfCasa.groupby('propertyType')['margen_ganancia'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(margen_promedio.index, margen_promedio.values, color='mediumorchid')
plt.title("Margen promedio de ganancia por tipo de propiedad")
plt.xlabel("Tipo de Propiedad")
plt.ylabel("Margen de Ganancia Promedio (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
